# %%
# %load_ext autoreload
# %autoreload 2

# %%
from federated_inference.common.utils import set_seed
from federated_inference.configs.data_config import DataConfiguration
from federated_inference.configs.transform_config import DataTransformConfiguration
from federated_inference.simulations.hybrid.simulation import HybridSplitSimulation

# %%
from federated_inference.simulations.hybrid.v1.models import GlobalHybridSplitClassifierHead, HybridSplitBase, LocalHybridSplitClassifierHead, RouterHead
DATASET = 'MNIST'
VERSION = "testv1"
for seed in [4]:
    set_seed(seed)
    data_config = DataConfiguration(DATASET)
    transform_config = DataTransformConfiguration()
    simulation2 = HybridSplitSimulation(seed, VERSION,  data_config, transform_config, GlobalHybridSplitClassifierHead, HybridSplitBase, LocalHybridSplitClassifierHead, RouterHead)
    simulation2.train()
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%
# MNIST training data loaded.
# MNIST test data loaded.
#
# Test set: Average loss per Sample: 0.0362, Accuracy: 1036/10000 (10%)
#
#
# Test set: Average loss per Sample: [0.037352285885810854, 0.03721330153942108, 0.036451373624801636, 0.037326293635368345], Accuracy: [904, 973, 1001, 957]/10000([9.04, 9.73, 10.01, 9.57]%)
#
# Epoch 1 | Batch 0 | Server Loss: 2.3363 | Classifier Losses: [2.3685, 2.4308, 2.3188, 2.3629]
# Epoch 1 | Batch 100 | Server Loss: 0.2571 | Classifier Losses: [1.0254, 0.7467, 0.8047, 0.9814]
# Epoch 1 | Batch 200 | Server Loss: 0.1720 | Classifier Losses: [1.1018, 0.7845, 0.6976, 1.0065]
# Epoch 1 | Batch 300 | Server Loss: 0.2815 | Classifier Losses: [1.3168, 0.7638, 0.834, 0.9253]
# Epoch 1 | Batch 400 | Server Loss: 0.1291 | Classifier Losses: [0.6931, 0.5292, 0.8485, 0.7027]
# Epoch 1 | Batch 500 | Server Loss: 0.2335 | Classifier Losses: [0.9332, 0.6203, 0.6921, 0.9096]
# Epoch 1 | Batch 600 | Server Loss: 0.3347 | Classifier Losses: [0.9502, 0.8124, 0.6494, 0.9378]
# Epoch 1 | Batch 700 | Server Loss: 0.1145 | Classifier Losses: [0.9504, 0.6289, 0.5725, 0.6694]
#
# Test set: Average loss per Sample: 0.0011, Accuracy: 9769/10000 (98%)
#
#
# Test set: Average loss per Sample: [0.01379443975687027, 0.010377741272747517, 0.010243072706460953, 0.013045907446742057], Accuracy: [6972, 7851, 7688, 7031]/10000([69.72, 78.51, 76.88, 70.31]%)
#
# Validation loss improved. Saving model...
# Epoch 2 | Batch 0 | Server Loss: 0.0685 | Classifier Losses: [1.0131, 0.4732, 0.4892, 1.0277]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       7 transform_config = DataTransformConfiguration()
#       8 simulation2 = HybridSplitSimulation(seed, VERSION,  data_config, transform_config, GlobalHybridSplitClassifierHead, HybridSplitBase, LocalHybridSplitClassifierHead, RouterHead)
# ----> 9 simulation2.train()
#
# File ~\Documents\workspace\dev\master\src\federated_inference\simulations\hybrid\simulation.py:25, in HybridSplitSimulation.train(self)
#      23 datasets = [client.send_all() for client in self.clients]
#      24 testsets = [client.request_pred(pred_all = True, keep_label = True) for client in self.clients]
# ---> 25 self.server.run_training(datasets, testsets)
#
# File ~\Documents\workspace\dev\master\src\federated_inference\simulations\hybrid\server.py:393, in HybridSplitServer.run_training(self, trainset, testset)
#     391 self.classifier_test()
#     392 for epoch in range(1, self.model_config.N_EPOCH + 1):
# --> 393     self.train(epoch)
#     394     self.test()
#     395     self.classifier_test()
#
# File ~\Documents\workspace\dev\master\src\federated_inference\simulations\hybrid\server.py:186, in HybridSplitServer.train(self, epoch)
#     185 def train(self, epoch):
# --> 186     for batch_idx, batches in enumerate(zip(*self.trainloader)):
#     187         data_slices = [batch[0].to(self.device).float() for batch in batches]
#     188         target = batches[0][1].to(self.device).long()
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torch\utils\data\_utils\fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torch\utils\data\dataset.py:416, in Subset.__getitems__(self, indices)
#     414     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     415 else:
# --> 416     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File ~\Documents\workspace\dev\master\src\federated_inference\transform\wrapper.py:17, in SensorWrapper.__getitem__(self, index)
#      16 def __getitem__(self, index: int) -> SensorView:
# ---> 17   data, target = self.dataset[index]
#      18   data = self._select_sensorview(data).evidence
#      19   if self.transform:
#
# File ~\Documents\workspace\dev\master\src\federated_inference\transform\wrapper.py:33, in DatasetWrapper.__getitem__(self, index)
#      32 def __getitem__(self, index: int) -> SensorView:
# ---> 33   data, target = self.dataset[index]
#      34   if self.transform:
#      35     data = self.transform(data)
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torchvision\datasets\mnist.py:146, in MNIST.__getitem__(self, index)
#     143 img = Image.fromarray(img.numpy(), mode="L")
#     145 if self.transform is not None:
# --> 146     img = self.transform(img)
#     148 if self.target_transform is not None:
#     149     target = self.target_transform(target)
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torchvision\transforms\transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)    135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File c:\Users\denis\Documents\workspace\env\Lib\site-packages\torchvision\transforms\functional.py:172, in to_tensor(pic)
#     170 if pic.mode == "1":
#     171     img = 255 * img
# --> 172 img = img.view(pic.size[1], pic.size[0], F_pil.get_image_num_channels(pic))
#     173 # put it from HWC to CHW format
#     174 img = img.permute((2, 0, 1)).contiguous()
#
# KeyboardInterrupt:

# %%
from federated_inference.simulations.hybrid.v2.models import GlobalHybridSplitClassifierHead, HybridSplitBase, LocalHybridSplitClassifierHead, RouterHead
DATASET = 'MNIST'
VERSION = "testv2"
for seed in [4]:
    set_seed(seed)
    data_config = DataConfiguration(DATASET)
    transform_config = DataTransformConfiguration()
    simulation2 = HybridSplitSimulation(seed, VERSION,  data_config, transform_config, GlobalHybridSplitClassifierHead, HybridSplitBase, LocalHybridSplitClassifierHead, RouterHead)
    simulation2.train()

# %%
from federated_inference.simulations.hybrid.v3.models import GlobalHybridSplitClassifierHead, HybridSplitBase, LocalHybridSplitClassifierHead, RouterHead
DATASET = 'MNIST'
VERSION = "testv3"
for seed in [4]:
    set_seed(seed)
    data_config = DataConfiguration(DATASET)
    transform_config = DataTransformConfiguration()
    simulation2 = HybridSplitSimulation(seed, VERSION,  data_config, transform_config, GlobalHybridSplitClassifierHead, HybridSplitBase, LocalHybridSplitClassifierHead, RouterHead)
    simulation2.train()
