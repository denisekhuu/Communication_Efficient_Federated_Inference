# %%
# %load_ext autoreload
# %autoreload 2

# %%
from federated_inference.configs.data_config import DataConfiguration
from federated_inference.configs.transform_config import DataTransformConfiguration

from federated_inference.configs.model_configs import OnDeviceModelConfiguration
from federated_inference.simulations.ondevice.client import OnDeviceVerticalClient

# %%
DATASET = 'MNIST'
VERSION = "testv1"
for seed in [1]:
    data_config = DataConfiguration(DATASET)
    transform_config = DataTransformConfiguration()
    simulation = OnDeviceVerticalSimulation(VERSION, data_config, transform_config, seed, OnDeviceMNISTModel, exist=False)
    simulation.train()
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\denis\Documents\workspace\env\Lib\site-packages\IPython\core\interactiveshell.py:3670 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from federated_inference.simulations.ondevice.models import OnDeviceCIFAR10Model
#
#   File ~\Documents\workspace\dev\master\src\federated_inference\simulations\ondevice\models.py:48
#     nn.Dropout(0.25)
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
